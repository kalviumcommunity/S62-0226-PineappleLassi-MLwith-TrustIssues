# %%
import pandas as pd

events = pd.read_csv("events.csv")
events_base = pd.read_csv("events_base.csv")

print(events.shape, events_base.shape)
# Out:
# (6892, 11) (6892, 11)

# %%
diff = (events != events_base).any(axis=1)
print("Modified rows:", diff.sum())
# Out:
# Modified rows: 6857
